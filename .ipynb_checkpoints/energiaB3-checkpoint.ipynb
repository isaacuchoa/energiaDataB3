# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados = pd.read_csv('caseEnergiaB3.csv')
dados
# Out:
#                     Data    Petrobras Aeris Energy       Alupar   AES Brasil  \
# 0    2021-03-22 00:00:00  23,07999992  9,279999733  24,60000038  31,10000038
# 1    2021-03-23 00:00:00  22,54999924   8,93999958  24,90999985        30,75
# 2    2021-03-24 00:00:00  22,53000069  9,020000458  24,61000061           30
# 3    2021-03-25 00:00:00  22,95999908  9,199999809  24,98999977  30,77000046
# 4    2021-03-26 00:00:00  23,29999924  9,100000381  25,29999924  30,27000046
# ..                   ...          ...          ...          ...          ...
# 246  2022-03-17 00:00:00  32,86999893  5,420000076  26,46999931        31,75
# 247  2022-03-18 00:00:00  33,15999985   5,71999979  26,55999947  32,22999954
# 248  2022-03-21 00:00:00  34,27000046  5,710000038  26,72999954  32,52000046
# 249  2022-03-22 00:00:00  34,04999924  5,800000191  26,70000076  32,95999908
# 250  2022-03-22 00:00:00  34,04999924  5,800000191  26,70000076  32,95999908
#
#            Cemig         Cesp
# ...

# %%
# Alterando tipo de dados e substituindo virgula por ponto

colunas = ['Petrobras','Aeris Energy','Alupar','AES Brasil','Cemig','Cesp'] 
dados[colunas] = dados[colunas].apply(lambda x: x.str.replace(',', '.').astype('float'))

# %%
dados
# Out:
#                     Data  Petrobras  Aeris Energy     Alupar  AES Brasil  \
# 0    2021-03-22 00:00:00  23.080000          9.28  24.600000   31.100000
# 1    2021-03-23 00:00:00  22.549999          8.94  24.910000   30.750000
# 2    2021-03-24 00:00:00  22.530001          9.02  24.610001   30.000000
# 3    2021-03-25 00:00:00  22.959999          9.20  24.990000   30.770000
# 4    2021-03-26 00:00:00  23.299999          9.10  25.299999   30.270000
# ..                   ...        ...           ...        ...         ...
# 246  2022-03-17 00:00:00  32.869999          5.42  26.469999   31.750000
# 247  2022-03-18 00:00:00  33.160000          5.72  26.559999   32.230000
# 248  2022-03-21 00:00:00  34.270000          5.71  26.730000   32.520000
# 249  2022-03-22 00:00:00  34.049999          5.80  26.700001   32.959999
# 250  2022-03-22 00:00:00  34.049999          5.80  26.700001   32.959999
#
#          Cemig       Cesp
# 0    11.040665  27.980000
# 1    11.040665  27.700001
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Data          251 non-null    object
#  1   Petrobras     251 non-null    float64
#  2   Aeris Energy  251 non-null    float64
#  3   Alupar        251 non-null    float64
#  4   AES Brasil    251 non-null    float64
#  5   Cemig         251 non-null    float64
#  6   Cesp          251 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 13.9+ KB

# %%
# pip install -U python-dateutil
'''
 atualização da lib dateutil para resolver conflitos de data
'''
# Out:
# '\n atualização da lib dateutil para resolver conflitos de data\n'

# %%
# Alterando coluna de data para o formato datetime

dados['Data'] = pd.to_datetime(dados['Data']).dt.strftime('%d%m%Y')

dados
# Out:
#          Data  Petrobras  Aeris Energy     Alupar  AES Brasil      Cemig  \
# 0    22032021  23.080000          9.28  24.600000   31.100000  11.040665
# 1    23032021  22.549999          8.94  24.910000   30.750000  11.040665
# 2    24032021  22.530001          9.02  24.610001   30.000000  10.816444
# 3    25032021  22.959999          9.20  24.990000   30.770000  11.157260
# 4    26032021  23.299999          9.10  25.299999   30.270000  11.148292
# ..        ...        ...           ...        ...         ...        ...
# 246  17032022  32.869999          5.42  26.469999   31.750000  13.540000
# 247  18032022  33.160000          5.72  26.559999   32.230000  13.990000
# 248  21032022  34.270000          5.71  26.730000   32.520000  14.270000
# 249  22032022  34.049999          5.80  26.700001   32.959999  14.310000
# 250  22032022  34.049999          5.80  26.700001   32.959999  14.310000
#
#           Cesp
# 0    27.980000
# 1    27.700001
# 2    27.330000
# 3    27.809999
# ...

# %%
# Setar o index para trabalhar com series temporais

dados.set_index('Data', inplace=True)
dados.head()
# Out:
#           Petrobras  Aeris Energy     Alupar  AES Brasil      Cemig       Cesp
# Data
# 22032021  23.080000          9.28  24.600000       31.10  11.040665  27.980000
# 23032021  22.549999          8.94  24.910000       30.75  11.040665  27.700001
# 24032021  22.530001          9.02  24.610001       30.00  10.816444  27.330000
# 25032021  22.959999          9.20  24.990000       30.77  11.157260  27.809999
# 26032021  23.299999          9.10  25.299999       30.27  11.148292  28.090000

# %%
# Gráfico

#Estilo do Gráfico
plt.style.use('seaborn-darkgrid')

# Tamanho
plt.figure(figsize=(16,8))

# Titulo
plt.title("Análise de ações de empresa de energia", loc='left', fontsize=18, fontweight=0)

# Texto da Petrobras
plt.text(dados.index[-1], dados['Petrobras'].tail(1), 'Petrobras', color='#003322', size='large', horizontalalignment='left')

# Plot da Petrobras
plt.plot(dados.index, dados['Petrobras'], color='#008c4a', linewidth=4, alpha=0.7);

#Plot das outras ações

for coluna in dados.columns[1:]:
    plt.plot(dados.index, dados[coluna], color='gray', linewidth=2, alpha=0.7);
    
    # Texto da Petrobras
    plt.text(dados.index[-1], dados[coluna].tail(1), coluna, color='#009988', size='large', horizontalalignment='left')
